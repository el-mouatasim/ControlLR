# %% [markdown]
# # use vtorch220

# %%
# Training and comparing

# %%
#! nvidia-smi

# %%
! python main_CLIP.py --clip_model_type ViT-B-32 --clip_pretrained laion2b_e16 --epochs 20 --typo 'ControlLR'
# Out:
# Runing :  ControlLR
# EPOCH 1: Train loss: 0.712433 Val loss: 0.689462 Val Acc:0.536885
# Model saved successfully.
# EPOCH 2: Train loss: 0.684290 Val loss: 0.710480 Val Acc:0.521516
# EPOCH 3: Train loss: 0.679519 Val loss: 0.688242 Val Acc:0.542520
# Model saved successfully.
# EPOCH 4: Train loss: 0.667806 Val loss: 0.695836 Val Acc:0.553791
# Model saved successfully.
# EPOCH 5: Train loss: 0.659661 Val loss: 0.683105 Val Acc:0.570184
# Model saved successfully.
# EPOCH 6: Train loss: 0.650819 Val loss: 0.683431 Val Acc:0.578893
# Model saved successfully.
# EPOCH 7: Train loss: 0.650688 Val loss: 0.684680 Val Acc:0.567111
# EPOCH 8: Train loss: 0.634537 Val loss: 0.683394 Val Acc:0.583504
# Model saved successfully.
# EPOCH 9: Train loss: 0.628893 Val loss: 0.676661 Val Acc:0.598873
# Model saved successfully.
# EPOCH 10: Train loss: 0.620174 Val loss: 0.675891 Val Acc:0.610656
# Model saved successfully.
# EPOCH 11: Train loss: 0.593394 Val loss: 0.666686 Val Acc:0.608094
# EPOCH 12: Train loss: 0.567415 Val loss: 0.672840 Val Acc:0.621414
# Model saved successfully.
# EPOCH 13: Train loss: 0.541440 Val loss: 0.671172 Val Acc:0.631148
# Model saved successfully.
# EPOCH 14: Train loss: 0.501254 Val loss: 0.688955 Val Acc:0.649078
# Model saved successfully.
# EPOCH 15: Train loss: 0.473285 Val loss: 0.642822 Val Acc:0.669057
# Model saved successfully.
# EPOCH 16: Train loss: 0.433441 Val loss: 0.662951 Val Acc:0.675205
# Model saved successfully.
# EPOCH 17: Train loss: 0.391885 Val loss: 0.656721 Val Acc:0.685963
# Model saved successfully.
# EPOCH 18: Train loss: 0.353001 Val loss: 0.658453 Val Acc:0.697234
# Model saved successfully.
# EPOCH 19: Train loss: 0.322770 Val loss: 0.695779 Val Acc:0.696209
# EPOCH 20: Train loss: 0.287583 Val loss: 0.690976 Val Acc:0.715164
# Model saved successfully.
# Val acc 0.7151639344262295
# Test acc 0.7057368941641938

# %%
! python main_CLIP.py --clip_model_type ViT-B-32 --clip_pretrained laion2b_e16 --epochs 20 --typo 'StepLR'
# Out:
# Runing :  StepLR
# EPOCH 1: Train loss: 0.702997 Val loss: 0.687560 Val Acc:0.555328
# Model saved successfully.
# EPOCH 2: Train loss: 0.681219 Val loss: 0.684618 Val Acc:0.566598
# Model saved successfully.
# EPOCH 3: Train loss: 0.670690 Val loss: 0.682718 Val Acc:0.570697
# Model saved successfully.
# EPOCH 4: Train loss: 0.665330 Val loss: 0.682504 Val Acc:0.571209
# Model saved successfully.
# EPOCH 5: Train loss: 0.660828 Val loss: 0.678280 Val Acc:0.569672
# EPOCH 6: Train loss: 0.651743 Val loss: 0.684866 Val Acc:0.569672
# EPOCH 7: Train loss: 0.642171 Val loss: 0.678388 Val Acc:0.591189
# Model saved successfully.
# EPOCH 8: Train loss: 0.637641 Val loss: 0.685954 Val Acc:0.582992
# EPOCH 9: Train loss: 0.621916 Val loss: 0.736710 Val Acc:0.554816
# EPOCH 10: Train loss: 0.618065 Val loss: 0.664174 Val Acc:0.610143
# Model saved successfully.
# EPOCH 11: Train loss: 0.589404 Val loss: 0.678352 Val Acc:0.612705
# Model saved successfully.
# EPOCH 12: Train loss: 0.564793 Val loss: 0.665252 Val Acc:0.622439
# Model saved successfully.
# EPOCH 13: Train loss: 0.525049 Val loss: 0.663213 Val Acc:0.625000
# Model saved successfully.
# EPOCH 14: Train loss: 0.518729 Val loss: 0.663236 Val Acc:0.622439
# EPOCH 15: Train loss: 0.512920 Val loss: 0.660837 Val Acc:0.629611
# Model saved successfully.
# EPOCH 16: Train loss: 0.507765 Val loss: 0.665659 Val Acc:0.629098
# EPOCH 17: Train loss: 0.501417 Val loss: 0.668155 Val Acc:0.628074
# EPOCH 18: Train loss: 0.498322 Val loss: 0.666606 Val Acc:0.628074
# EPOCH 19: Train loss: 0.491238 Val loss: 0.665059 Val Acc:0.631148
# Model saved successfully.
# EPOCH 20: Train loss: 0.489037 Val loss: 0.662211 Val Acc:0.629611
# Val acc 0.6296106557377049
# Test acc 0.6340257171117705

# %%
! python main_CLIP.py --clip_model_type ViT-B-32 --clip_pretrained laion2b_e16 --epochs 20 --typo 'ExponentialLR'
# Out:
# Runing :  ExponentialLR
# EPOCH 1: Train loss: 0.694418 Val loss: 0.682976 Val Acc:0.556865
# Model saved successfully.
# EPOCH 2: Train loss: 0.676968 Val loss: 0.684987 Val Acc:0.564549
# Model saved successfully.
# EPOCH 3: Train loss: 0.665743 Val loss: 0.718383 Val Acc:0.531250
# EPOCH 4: Train loss: 0.665965 Val loss: 0.694494 Val Acc:0.550205
# EPOCH 5: Train loss: 0.654906 Val loss: 0.684749 Val Acc:0.573258
# Model saved successfully.
# EPOCH 6: Train loss: 0.649787 Val loss: 0.703597 Val Acc:0.558402
# EPOCH 7: Train loss: 0.642161 Val loss: 0.692966 Val Acc:0.566086
# EPOCH 8: Train loss: 0.637407 Val loss: 0.693068 Val Acc:0.575307
# Model saved successfully.
# EPOCH 9: Train loss: 0.633494 Val loss: 0.691360 Val Acc:0.571721
# EPOCH 10: Train loss: 0.630720 Val loss: 0.686763 Val Acc:0.579918
# Model saved successfully.
# EPOCH 11: Train loss: 0.625645 Val loss: 0.689748 Val Acc:0.582480
# Model saved successfully.
# EPOCH 12: Train loss: 0.625718 Val loss: 0.681354 Val Acc:0.590164
# Model saved successfully.
# EPOCH 13: Train loss: 0.617260 Val loss: 0.686137 Val Acc:0.595799
# Model saved successfully.
# EPOCH 14: Train loss: 0.610849 Val loss: 0.687053 Val Acc:0.595799
# EPOCH 15: Train loss: 0.604373 Val loss: 0.683991 Val Acc:0.592213
# EPOCH 16: Train loss: 0.596602 Val loss: 0.682043 Val Acc:0.599898
# Model saved successfully.
# EPOCH 17: Train loss: 0.591548 Val loss: 0.682320 Val Acc:0.600922
# Model saved successfully.
# EPOCH 18: Train loss: 0.588444 Val loss: 0.683137 Val Acc:0.606557
# Model saved successfully.
# EPOCH 19: Train loss: 0.580991 Val loss: 0.679695 Val Acc:0.599898
# EPOCH 20: Train loss: 0.572746 Val loss: 0.678877 Val Acc:0.608607
# Model saved successfully.
# Val acc 0.6086065573770492
# Test acc 0.6147378832838774

# %% [markdown]
# # Plotter

# %%
import matplotlib.pyplot as plt
import re
import numpy as np
import csv

# %%
#fig = plt.figure(figsize=(10,5))

def read(name):
    f = open(name, 'r')
    file = f.read()
    file = re.sub('\\[', '', file)
    file = re.sub('\\]', '', file)
    f.close()

    return [float(i) for idx, i in enumerate(file.split(','))]


def draw(modn,mode):
        
    if mode == 'train loss':
        clr = read('./results/{}/train_loss_ControlLR.txt'.format(modn))
        adam = read('./results/{}/train_loss_StepLR.txt'.format(modn))
        ExponentialLR = read('./results/{}/train_loss_ExponentialLR.txt'.format(modn))
        plt.plot(clr, 'r', label='ControlLR')
        plt.plot(adam, 'b', label='StepLR')
        plt.plot(ExponentialLR, 'g', label='ExponentialLR')
        plt.legend(loc='lower left')

    elif mode == 'valid loss':
        clr = read('./results/{}/valid_loss_ControlLR.txt'.format(modn))
        adam = read('./results/{}/valid_loss_StepLR.txt'.format(modn))
        ExponentialLR = read('./results/{}/valid_loss_ExponentialLR.txt'.format(modn))
        plt.plot(clr, 'r', label='ControlLR')
        plt.plot(adam, 'b', label='StepLR')
        plt.plot(ExponentialLR, 'g', label='ExponentialLR')
        plt.legend(loc='lower left')
  

    elif mode == 'valid acc':
        clr = read('./results/{}/valid_acc_ControlLR.txt'.format(modn))
        adam = read('./results/{}/valid_acc_StepLR.txt'.format(modn))
        ExponentialLR = read('./results/{}/valid_acc_ExponentialLR.txt'.format(modn))
        plt.plot(clr, 'r', label='ControlLR')
        plt.plot(adam, 'b', label='StepLR')
        plt.plot(ExponentialLR, 'g', label='ExponentialLR')
        plt.legend(loc='best')
        
    plt.xlabel('epoch')
    plt.ylabel(mode)
    plt.title('training result of Adam in model {}'.format(modn))
    plt.grid(True, which='both', axis='both')
    plt.savefig('./png/{}/{}.png'.format(modn, mode))
    plt.show()
modn = 'Clip'
draw(modn, mode='train loss')
draw(modn, mode='valid loss')
    
draw(modn, mode='valid acc')
